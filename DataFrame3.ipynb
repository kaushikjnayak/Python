# %%
import pandas as pd
employees = pd.read_csv('C:/Users/kaushik/PycharmProjects/PRJ_2/EMPLOYEES.csv')
departments = pd.read_csv('C:/Users/kaushik/PycharmProjects/PRJ_2/DEPARTMENTS.csv')

# %%
employees.set_index('EMPLOYEE_ID', inplace = True)
departments.set_index('DEPARTMENT_ID', inplace = True)

# %%
employees.head()
# Out:
#             FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER HIRE_DATE   JOB_ID  \
# EMPLOYEE_ID
# 100             Steven      King     SKING  515.123.4567  17-06-03  AD_PRES
# 101              Neena   Kochhar  NKOCHHAR  515.123.4568  21-09-05    AD_VP
# 102                Lex   De Haan   LDEHAAN  515.123.4569  13-01-01    AD_VP
# 103          Alexander    Hunold   AHUNOLD  590.423.4567  03-01-06  IT_PROG
# 104              Bruce     Ernst    BERNST  590.423.4568  21-05-07  IT_PROG
#
#              SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# EMPLOYEE_ID
# 100           24000             NaN         NaN           90.0
# 101           17000             NaN       100.0           90.0
# 102           17000             NaN       100.0           90.0
# 103            9000             NaN       102.0           60.0
# 104            6000             NaN       103.0           60.0

# %%
departments.head()
# Out:
#                DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# DEPARTMENT_ID
# 10              Administration       200.0         1700
# 20                   Marketing       201.0         1800
# 30                  Purchasing       114.0         1700
# 40             Human Resources       203.0         2400
# 50                    Shipping       121.0         1500

# %%
e2 = employees.set_index('DEPARTMENT_ID')
pd.concat ( [ e2[['FIRST_NAME','LAST_NAME']] , departments ]) # Join Employees with departments
# Out:
#                     DEPARTMENT_NAME   FIRST_NAME    LAST_NAME  LOCATION_ID  \
# DEPARTMENT_ID
# 90.0                            NaN       Steven         King          NaN
# 90.0                            NaN        Neena      Kochhar          NaN
# 90.0                            NaN          Lex      De Haan          NaN
# 60.0                            NaN    Alexander       Hunold          NaN
# 60.0                            NaN        Bruce        Ernst          NaN
# 60.0                            NaN        David       Austin          NaN
# 60.0                            NaN        Valli    Pataballa          NaN
# 60.0                            NaN        Diana      Lorentz          NaN
# 100.0                           NaN        Nancy    Greenberg          NaN
# 100.0                           NaN       Daniel       Faviet          NaN
# 100.0                           NaN         John         Chen          NaN
# ...

# %%
myemployees = pd.Series( ['Steven','Alexander'], index = [100,103])

# %%
myemployees
# Out:
# 100       Steven
# 103    Alexander
# dtype: object

# %%
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import numpy as np
frameabcd = pd.DataFrame(np.arange(4),index=list('abcd'), columns=['NUM'])
frameabcd
seriesabcd = frameabcd.loc['a']
seriesabcd
# Out:
# NUM    0
# Name: a, dtype: int32

# %%
frameabcd + seriesabcd
# Out:
#    NUM
# a    0
# b    1
# c    2
# d    3

# %%
employees.head()
employees['SALARY'] = employees['SALARY'].apply(lambda x : int(x * 1.25))
employees.head()
employees[employees['SALARY'] > 10000]
employees[employees['SALARY'] > 10000].min()
# Out:
# FIRST_NAME                      Adam
# LAST_NAME                       Abel
# EMAIL                       AERRAZUR
# PHONE_NUMBER      011.44.1343.729268
# HIRE_DATE                   01-08-04
# JOB_ID                    AC_ACCOUNT
# SALARY                         10250
# COMMISSION_PCT                  0.15
# MANAGER_ID                       100
# DEPARTMENT_ID                     20
# dtype: object

# %%
#Display columns in sorted (descending in this case) order
employees.sort_index(axis = 1, ascending = False)

#Order employes by decreasing salaries
employees.sort_values(by='SALARY', ascending = False)

#Rank Salaries and append it as a new column 
employees['RANK'] = employees['SALARY'].rank() #Defalut is by weigthed average 
employees['RANK'] = employees['SALARY'].rank(method = 'first') # order of appearance
employees['RANK'] = employees['SALARY'].rank(method = 'min') # In a series [1,2 3,3,5] 3 and 3 are ranked 3, 5 is ranked 5
employees['RANK'] = employees['SALARY'].rank(method = 'max') # In a series [1,2 3,3,5] 3 and 3 are ranked 4, 5 is ranked 5
employees['RANK'] = employees['SALARY'].rank(method = 'max') # In a series [1,2 3,3,5] 3 and 3 are 3, 5 is ranked 4

# %%
#Sort the entire dataframe by rank
employees.sort_values(by='RANK', ascending = False)
# Out:
#             FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER HIRE_DATE  \
# EMPLOYEE_ID
# 100             Steven         King     SKING        515.123.4567  17-06-03
# 102                Lex      De Haan   LDEHAAN        515.123.4569  13-01-01
# 101              Neena      Kochhar  NKOCHHAR        515.123.4568  21-09-05
# 145               John      Russell   JRUSSEL  011.44.1344.429268  01-10-04
# 146              Karen     Partners  KPARTNER  011.44.1344.467268  05-01-05
# 201            Michael    Hartstein  MHARTSTE        515.123.5555  17-02-04
# 108              Nancy    Greenberg  NGREENBE        515.124.4569  17-08-02
# 205            Shelley      Higgins  SHIGGINS        515.123.8080  07-06-02
# 147            Alberto    Errazuriz  AERRAZUR  011.44.1344.429278  10-03-05
# 168               Lisa         Ozer     LOZER  011.44.1343.929268  11-03-05
# 148             Gerald    Cambrault  GCAMBRAU  011.44.1344.619268  15-10-07
# ...

# %%
obj = pd.Series([1, 2, 3, 3, 5])

# %%
obj.rank(method='first')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
obj.rank(method='min')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    5.0
# dtype: float64

# %%
obj.rank(method='max')
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
obj.rank(method='dense')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    4.0
# dtype: float64

# %%
employees['SALARY'].sum() #sum across columns
# Out:
# 691416

# %%
employees['FIRST_NAME'].sum() #appends all the fisrtname into single string
# Out:
# 'StevenNeenaLexAlexanderBruceDavidValliDianaNancyDanielJohnIsmaelJose ...'

# %%
#minimum saa]lary till the point of reference.
employees.set_index('DEPARTMENT_ID').sort_index()['SALARY'].cummin()

#Percentage change in Salary across departments for each employee.
employees.set_index('DEPARTMENT_ID').sort_index()['SALARY'].pct_change()
#unique FIRSTNAME as an array
employees['FIRST_NAME'].unique()
#No of occurences of each Fname.
employees['FIRST_NAME'].value_counts()

#Check for existence of firstname .
employees[employees['FIRST_NAME'].isin(['Kaushik','Namrata','Michael'])]
# Out:
#              FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  HIRE_DATE  JOB_ID  \
# EMPLOYEE_ID
# 100                94.5       52.5   90.0          37.0       57.0     4.0
# 101                75.0       54.0   74.0          38.0       75.0     5.5
# 102                61.0       21.0   61.0          39.0       40.0     5.5
# 103                 4.5       46.0    6.0          58.0        5.0    16.0
# 104                12.0       25.0   11.0          59.0       72.0    16.0
# 105                20.0        4.0   17.0          60.0       95.0    16.0
# 106               103.0       77.0  104.0          57.0       13.0    16.0
# 107                23.0       60.0   23.0          61.0       16.5    16.0
# 108                72.0       40.0   73.0          50.0       58.0    12.0
# 109                17.0       28.0   19.0          45.0       53.0     9.0
# 110                46.0       17.0   38.0          46.0       99.0     9.0
# ...
